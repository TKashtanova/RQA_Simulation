# %% [markdown]
# The commands to run the gDPM simulation package in Google Colab.
#
# Put together by Samuel Ydenberg
#
#
#
# References:
#
# [1] Nechaev, I (2019) nvcc4jupyter [Source Code]. https://github.com/andreinechaev/nvcc4jupyter
#
# [2] Google. “External Data: Local Files, Drive, Sheets, and Cloud Storage.” Google Colab
#
# [3] Singh Side, K (2022) Google-Colab-Shell [Source Code]. https://github.com/singhsidhukuldeep/Google-Colab-Shell

# %%
# Check the compiler version
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# Package to use the nvcc compiler [1]
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Link to one's google drive [2]
# !apt-get install cuda-thrust-dev
# !apt-get install cuda-thrust-doc
# !pip install google-colab-shell
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-y55l1qw0
#   Running command git clone --filter=blob:none --quiet https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-y55l1qw0
#   Resolved https://github.com/andreinechaev/nvcc4jupyter.git to commit aac710a35f52bb78ab34d2e52517237941399eff
#   Preparing metadata (setup.py) ... done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package cuda-thrust-dev
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package cuda-thrust-doc
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import Google Colab shell [3]
from google_colab_shell import getshell
getshell()
# Out:
# <!--https://github.com/singhsidhukuldeep/Google-Colab-Shell/-->
# <!--Using JS/CSS from official sources with backups in-case :)-->
# <div id=colab_shell></div>
# <script src="https://code.jquery.com/jquery-latest.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/jquery.terminal/js/jquery.terminal.min.js"></script>
# <link href="https://cdn.jsdelivr.net/npm/jquery.terminal/css/jquery.terminal.min.css" rel="stylesheet"/>
# <script>
#    $('#colab_shell').terminal(async function(command) {
#        if (command !== '') {
#            try {
#                let res = await google.colab.kernel.invokeFunction('shell', [command])
#                let out = res.data['application/json'][0]
#                this.echo(new String(out))
#            } catch(e) {
#                this.error(new String(e));
#            }
#        } else {
#            this.echo(
#              //   '>>Empty Command<<\n'+
#              //   'If you can afford use Google Colab Pro'
#                );
# ...

# %%
# !make clean
# Out:
# rm obj/*
# rm gdpm

# %%
# !make
# Out:
# nvcc src/global.cpp src/main.cu -dc -I ./inc -std=c++11 -w -dlto
# mv *.o obj
# nvcc obj/*.o -o gdpm

# %%
# !./gdpm
# Out:
# Streaming output truncated to the last 5000 lines.
# photon started, nactive is 327680
# New size: 3483
# photon started, nactive is 327680
# New size: 3548
# photon started, nactive is 327680
# New size: 3423
# photon started, nactive is 327680
# New size: 3457
# photon started, nactive is 327680
# New size: 3508
# photon started, nactive is 327680
# New size: 3431
# photon started, nactive is 327680
# New size: 3492
# photon started, nactive is 327680
# New size: 3433
# photon started, nactive is 327680
# New size: 3570
# photon started, nactive is 327680
# New size: 3590
# photon started, nactive is 327680
# New size: 3414
# photon started, nactive is 327680
# New size: 3578
# photon started, nactive is 327680
# New size: 3480
# photon started, nactive is 327680
# New size: 4851
# photon started, nactive is 327680
# New size: 3503
# photon started, nactive is 327680
# New size: 3449
# photon started, nactive is 327680
# New size: 3516
# photon started, nactive is 327680
# ...
